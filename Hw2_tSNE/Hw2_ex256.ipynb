# %% [markdown]
# # Tống Thị Vân Anh - 11200365

# %% [markdown]
# ## 1. Biến đổi lại công thức toán SNE, t-SNE, có tính đạo hàm loss với các parameter
# (overleaf)

# %% [markdown]
# ## 2. Dùng thư viện sklearn, chạy lại với các dataset dưới, nhận xét khi thay đổi perplexity, [link](https://scikit-learn.org/stable/auto_examples/manifold/plot_t_sne_perplexity.html#sphx-glr-auto-examples-manifold-plot-t-sne-perplexity-py)

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.ticker import NullFormatter
from sklearn import manifold, datasets
from time import time

n_samples = 150
n_components = 2
(fig, subplots) = plt.subplots(3, 5, figsize=(15, 8))
perplexities = [5, 30, 50, 100]

X, y = datasets.make_circles(
    n_samples=n_samples, factor=0.5, noise=0.05, random_state=0
)

red = y == 0
green = y == 1

ax = subplots[0][0]
ax.scatter(X[red, 0], X[red, 1], c="r")
ax.scatter(X[green, 0], X[green, 1], c="g")
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis("tight")

for i, perplexity in enumerate(perplexities):
    ax = subplots[0][i + 1]

    t0 = time()
    tsne = manifold.TSNE(
        n_components=n_components,
        init="random",
        random_state=0,
        perplexity=perplexity,
        n_iter=300,
    )
    Y = tsne.fit_transform(X)
    t1 = time()
    print("circles, perplexity=%d in %.2g sec" % (perplexity, t1 - t0))
    ax.set_title("Perplexity=%d" % perplexity)
    ax.scatter(Y[red, 0], Y[red, 1], c="r")
    ax.scatter(Y[green, 0], Y[green, 1], c="g")
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis("tight")

# Another example using s-curve
X, color = datasets.make_s_curve(n_samples, random_state=0)

ax = subplots[1][0]
ax.scatter(X[:, 0], X[:, 2], c=color)
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())

for i, perplexity in enumerate(perplexities):
    ax = subplots[1][i + 1]

    t0 = time()
    tsne = manifold.TSNE(
        n_components=n_components,
        init="random",
        random_state=0,
        perplexity=perplexity,
        learning_rate="auto",
        n_iter=300,
    )
    Y = tsne.fit_transform(X)
    t1 = time()
    print("S-curve, perplexity=%d in %.2g sec" % (perplexity, t1 - t0))

    ax.set_title("Perplexity=%d" % perplexity)
    ax.scatter(Y[:, 0], Y[:, 1], c=color)
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis("tight")


# Another example using a 2D uniform grid
x = np.linspace(0, 1, int(np.sqrt(n_samples)))
xx, yy = np.meshgrid(x, x)
X = np.hstack(
    [
        xx.ravel().reshape(-1, 1),
        yy.ravel().reshape(-1, 1),
    ]
)
color = xx.ravel()
ax = subplots[2][0]
ax.scatter(X[:, 0], X[:, 1], c=color)
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())

for i, perplexity in enumerate(perplexities):
    ax = subplots[2][i + 1]

    t0 = time()
    tsne = manifold.TSNE(
        n_components=n_components,
        init="random",
        random_state=0,
        perplexity=perplexity,
        n_iter=400,
    )
    Y = tsne.fit_transform(X)
    t1 = time()
    print("uniform grid, perplexity=%d in %.2g sec" % (perplexity, t1 - t0))

    ax.set_title("Perplexity=%d" % perplexity)
    ax.scatter(Y[:, 0], Y[:, 1], c=color)
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis("tight")


plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# circles, perplexity=5 in 0.61 sec
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# circles, perplexity=30 in 0.86 sec
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# circles, perplexity=50 in 0.77 sec
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# circles, perplexity=100 in 0.81 sec
# S-curve, perplexity=5 in 0.9 sec
# S-curve, perplexity=30 in 0.88 sec
# S-curve, perplexity=50 in 1 sec
# S-curve, perplexity=100 in 0.98 sec
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# uniform grid, perplexity=5 in 0.77 sec
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# uniform grid, perplexity=30 in 2.8 sec
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# uniform grid, perplexity=50 in 3.4 sec
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# uniform grid, perplexity=100 in 1.8 sec

# %% [markdown]
# ### **Comment**
#
# 1. circles:
#  t-SNE for higher perplexities finds meaningful topology of two concentric circles, however the size and the distance of the circles varies slightly from the original.
#
# 2. S-curve:
# the shapes visually diverge from S-curve topology on the S-curve dataset even for larger perplexity values.
#
# 3. uniform grid:
# Try convergence: the size of square and the distance between the points are shrinking, especially the points at the edges, and converging at the corners. Edges tend to curve more as perplexity increases, making the overall shape appear rounder.

# %% [markdown]
# ## 3. Dùng word embedding [link](https://habr.com/en/company/vk/blog/449984/), chọn ra 10 từ bất kì, với mỗi từ tìm 10 từ có embedding gần nhất
# a. nhận xét về ngữ nghĩa các từ có embedding gần nhau
#
# b. dùng t-SNE giảm chiều các vector embedding về 2 chiều, nhận xét các cụm
#
# (làm ở file khác)

# %% [markdown]
# ## 4. So sánh t-SNE và PCA
# (overleaf)

# %% [markdown]
# ## 5. Đọc [paper](https://www.jmlr.org/papers/volume9/vandermaaten08a/vandermaaten08a.pdf)

# %% [markdown]
# ## 6. (optional) tự implement lại t-SNE, variance có thể fix hoặc từ perplexity tìm ra

# %%
import numpy as np
from sklearn.datasets import load_digits
from scipy.spatial.distance import pdist
from sklearn.manifold._t_sne import _joint_probabilities
from scipy import linalg
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import squareform
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
palette = sns.color_palette("bright", 10)

# %%
X, y = load_digits(return_X_y=True)

# %%
MACHINE_EPSILON = np.finfo(np.double).eps
n_components = 2
perplexity = 30

# %%
def _kl_divergence(params, P, degrees_of_freedom, n_samples, n_components):
    X_embedded = params.reshape(n_samples, n_components)
    
    dist = pdist(X_embedded, "sqeuclidean")
    dist /= degrees_of_freedom
    dist += 1.
    dist **= (degrees_of_freedom + 1.0) / -2.0
    Q = np.maximum(dist / (2.0 * np.sum(dist)), MACHINE_EPSILON)
    
    # Kullback-Leibler divergence of P and Q
    kl_divergence = 2.0 * np.dot(P, np.log(np.maximum(P, MACHINE_EPSILON) / Q))
    
    # Gradient: dC/dY
    grad = np.ndarray((n_samples, n_components), dtype=params.dtype)
    PQd = squareform((P - Q) * dist)
    for i in range(n_samples):
        grad[i] = np.dot(np.ravel(PQd[i], order='K'),
                         X_embedded[i] - X_embedded)
    grad = grad.ravel()
    c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
    grad *= c
    return kl_divergence, grad

# %%
def _gradient_descent(obj_func, p0, args, it=0, n_iter=1000,
                      n_iter_check=1, n_iter_without_progress=300,
                      momentum=0.8, learning_rate=200.0, min_gain=0.01,
                      min_grad_norm=1e-7):
    
    p = p0.copy().ravel()
    update = np.zeros_like(p)
    gains = np.ones_like(p)
    error = np.finfo(np.float).max
    best_error = np.finfo(np.float).max
    best_iter = i = it
    
    for i in range(it, n_iter):
        error, grad = obj_func(p, *args)
        grad_norm = linalg.norm(grad)
        inc = update * grad < 0.0
        dec = np.invert(inc)
        gains[inc] += 0.2
        gains[dec] *= 0.8
        np.clip(gains, min_gain, np.inf, out=gains)
        grad *= gains
        update = momentum * update - learning_rate * grad
        p += update
        print("[t-SNE] Iteration %d: error = %.7f,"
                      " gradient norm = %.7f"
                      % (i + 1, error, grad_norm))
        
        if error < best_error:
                best_error = error
                best_iter = i
        elif i - best_iter > n_iter_without_progress:
            break
        
        if grad_norm <= min_grad_norm:
            break
    return p

# %%
def _tsne(P, degrees_of_freedom, n_samples, X_embedded):
    params = X_embedded.ravel()
    
    obj_func = _kl_divergence
    
    params = _gradient_descent(obj_func, params, [P, degrees_of_freedom, n_samples, n_components])
        
    X_embedded = params.reshape(n_samples, n_components)
    return X_embedded

# %%
def fit(X):
    n_samples = X.shape[0]
    
    # Compute euclidean distance
    distances = pairwise_distances(X, metric='euclidean', squared=True)
    
    # Compute joint probabilities p_ij from distances.
    P = _joint_probabilities(distances=distances, desired_perplexity=perplexity, verbose=False)
    
    # The embedding is initialized with iid samples from Gaussians with standard deviation 1e-4.
    X_embedded = 1e-4 * np.random.mtrand._rand.randn(n_samples, n_components).astype(np.float32)
    
    # degrees_of_freedom = n_components - 1 comes from
    # "Learning a Parametric Embedding by Preserving Local Structure"
    # Laurens van der Maaten, 2009.
    degrees_of_freedom = max(n_components - 1, 1)
    
    return _tsne(P, degrees_of_freedom, n_samples, X_embedded=X_embedded)

# %%
X_embedded = fit(X)
# Out:
# <ipython-input-5-d138dd81716d>:9: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   error = np.finfo(np.float).max
# <ipython-input-5-d138dd81716d>:10: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   best_error = np.finfo(np.float).max
# [t-SNE] Iteration 1: error = 3.9810953, gradient norm = 0.0000046
# [t-SNE] Iteration 2: error = 3.9810953, gradient norm = 0.0000046
# [t-SNE] Iteration 3: error = 3.9810953, gradient norm = 0.0000055
# [t-SNE] Iteration 4: error = 3.9810953, gradient norm = 0.0000083
# [t-SNE] Iteration 5: error = 3.9810952, gradient norm = 0.0000140
# [t-SNE] Iteration 6: error = 3.9810951, gradient norm = 0.0000252
# [t-SNE] Iteration 7: error = 3.9810945, gradient norm = 0.0000483
# [t-SNE] Iteration 8: error = 3.9810923, gradient norm = 0.0000978
# [t-SNE] Iteration 9: error = 3.9810823, gradient norm = 0.0002088
# [t-SNE] Iteration 10: error = 3.9810322, gradient norm = 0.0004674
# [t-SNE] Iteration 11: error = 3.9807579, gradient norm = 0.0010934
# [t-SNE] Iteration 12: error = 3.9791330, gradient norm = 0.0026471
# [t-SNE] Iteration 13: error = 3.9690662, gradient norm = 0.0063649
# [t-SNE] Iteration 14: error = 3.9130585, gradient norm = 0.0128812
# [t-SNE] Iteration 15: error = 3.7197171, gradient norm = 0.0174596
# [t-SNE] Iteration 16: error = 3.3867564, gradient norm = 0.0161855
# [t-SNE] Iteration 17: error = 3.0509832, gradient norm = 0.0128052
# [t-SNE] Iteration 18: error = 2.7753454, gradient norm = 0.0106566
# [t-SNE] Iteration 19: error = 2.5486107, gradient norm = 0.0093207
# [t-SNE] Iteration 20: error = 2.3576712, gradient norm = 0.0082693
# [t-SNE] Iteration 21: error = 2.1970224, gradient norm = 0.0073371
# [t-SNE] Iteration 22: error = 2.0647505, gradient norm = 0.0064729
# [t-SNE] Iteration 23: error = 1.9589037, gradient norm = 0.0058244
# [t-SNE] Iteration 24: error = 1.8732616, gradient norm = 0.0054338
# [t-SNE] Iteration 25: error = 1.8025230, gradient norm = 0.0051444
# [t-SNE] Iteration 26: error = 1.7430903, gradient norm = 0.0048802
# [t-SNE] Iteration 27: error = 1.6924178, gradient norm = 0.0046319
# [t-SNE] Iteration 28: error = 1.6488661, gradient norm = 0.0043510
# [t-SNE] Iteration 29: error = 1.6114916, gradient norm = 0.0041118
# [t-SNE] Iteration 30: error = 1.5792115, gradient norm = 0.0039380
# [t-SNE] Iteration 31: error = 1.5508881, gradient norm = 0.0037646
# [t-SNE] Iteration 32: error = 1.5255804, gradient norm = 0.0035467
# [t-SNE] Iteration 33: error = 1.5029201, gradient norm = 0.0033696
# [t-SNE] Iteration 34: error = 1.4823127, gradient norm = 0.0032362
# [t-SNE] Iteration 35: error = 1.4632459, gradient norm = 0.0031059
# [t-SNE] Iteration 36: error = 1.4454076, gradient norm = 0.0030009
# [t-SNE] Iteration 37: error = 1.4285568, gradient norm = 0.0028879
# [t-SNE] Iteration 38: error = 1.4126006, gradient norm = 0.0027898
# [t-SNE] Iteration 39: error = 1.3973840, gradient norm = 0.0026471
# [t-SNE] Iteration 40: error = 1.3832205, gradient norm = 0.0024776
# [t-SNE] Iteration 41: error = 1.3703723, gradient norm = 0.0023294
# [t-SNE] Iteration 42: error = 1.3586182, gradient norm = 0.0022305
# [t-SNE] Iteration 43: error = 1.3474477, gradient norm = 0.0021521
# [t-SNE] Iteration 44: error = 1.3370196, gradient norm = 0.0020430
# [t-SNE] Iteration 45: error = 1.3274838, gradient norm = 0.0020182
# [t-SNE] Iteration 46: error = 1.3183498, gradient norm = 0.0019690
# [t-SNE] Iteration 47: error = 1.3100384, gradient norm = 0.0019324
# [t-SNE] Iteration 48: error = 1.3021513, gradient norm = 0.0018720
# [t-SNE] Iteration 49: error = 1.2942285, gradient norm = 0.0017691
# [t-SNE] Iteration 50: error = 1.2863679, gradient norm = 0.0016533
# [t-SNE] Iteration 51: error = 1.2787419, gradient norm = 0.0015466
# [t-SNE] Iteration 52: error = 1.2714453, gradient norm = 0.0015021
# [t-SNE] Iteration 53: error = 1.2643489, gradient norm = 0.0014780
# [t-SNE] Iteration 54: error = 1.2573897, gradient norm = 0.0014241
# [t-SNE] Iteration 55: error = 1.2506222, gradient norm = 0.0013831
# [t-SNE] Iteration 56: error = 1.2440089, gradient norm = 0.0013558
# [t-SNE] Iteration 57: error = 1.2375200, gradient norm = 0.0013375
# [t-SNE] Iteration 58: error = 1.2311134, gradient norm = 0.0013118
# [t-SNE] Iteration 59: error = 1.2247654, gradient norm = 0.0012696
# [t-SNE] Iteration 60: error = 1.2184893, gradient norm = 0.0012268
# [t-SNE] Iteration 61: error = 1.2123097, gradient norm = 0.0012029
# [t-SNE] Iteration 62: error = 1.2062090, gradient norm = 0.0011953
# [t-SNE] Iteration 63: error = 1.2001306, gradient norm = 0.0011834
# [t-SNE] Iteration 64: error = 1.1940308, gradient norm = 0.0011662
# [t-SNE] Iteration 65: error = 1.1878887, gradient norm = 0.0011542
# [t-SNE] Iteration 66: error = 1.1816867, gradient norm = 0.0011373
# [t-SNE] Iteration 67: error = 1.1754566, gradient norm = 0.0011141
# [t-SNE] Iteration 68: error = 1.1693136, gradient norm = 0.0011010
# [t-SNE] Iteration 69: error = 1.1632970, gradient norm = 0.0011027
# [t-SNE] Iteration 70: error = 1.1573455, gradient norm = 0.0010846
# [t-SNE] Iteration 71: error = 1.1515516, gradient norm = 0.0010539
# [t-SNE] Iteration 72: error = 1.1460980, gradient norm = 0.0010985
# [t-SNE] Iteration 73: error = 1.1409050, gradient norm = 0.0011644
# [t-SNE] Iteration 74: error = 1.1358369, gradient norm = 0.0011582
# [t-SNE] Iteration 75: error = 1.1308629, gradient norm = 0.0011177
# [t-SNE] Iteration 76: error = 1.1259600, gradient norm = 0.0010405
# [t-SNE] Iteration 77: error = 1.1212104, gradient norm = 0.0009720
# [t-SNE] Iteration 78: error = 1.1166545, gradient norm = 0.0009522
# [t-SNE] Iteration 79: error = 1.1122486, gradient norm = 0.0009333
# [t-SNE] Iteration 80: error = 1.1079774, gradient norm = 0.0009052
# [t-SNE] Iteration 81: error = 1.1038618, gradient norm = 0.0008721
# [t-SNE] Iteration 82: error = 1.0999116, gradient norm = 0.0008307
# [t-SNE] Iteration 83: error = 1.0961187, gradient norm = 0.0008188
# [t-SNE] Iteration 84: error = 1.0924322, gradient norm = 0.0008115
# [t-SNE] Iteration 85: error = 1.0888137, gradient norm = 0.0007984
# [t-SNE] Iteration 86: error = 1.0852484, gradient norm = 0.0007740
# [t-SNE] Iteration 87: error = 1.0817394, gradient norm = 0.0007475
# [t-SNE] Iteration 88: error = 1.0782838, gradient norm = 0.0007264
# [t-SNE] Iteration 89: error = 1.0748744, gradient norm = 0.0007107
# [t-SNE] Iteration 90: error = 1.0715048, gradient norm = 0.0006944
# [t-SNE] Iteration 91: error = 1.0681754, gradient norm = 0.0006843
# [t-SNE] Iteration 92: error = 1.0648801, gradient norm = 0.0006661
# [t-SNE] Iteration 93: error = 1.0616309, gradient norm = 0.0006511
# [t-SNE] Iteration 94: error = 1.0584308, gradient norm = 0.0006406
# [t-SNE] Iteration 95: error = 1.0552660, gradient norm = 0.0006394
# [t-SNE] Iteration 96: error = 1.0521251, gradient norm = 0.0006382
# [t-SNE] Iteration 97: error = 1.0490318, gradient norm = 0.0006451
# [t-SNE] Iteration 98: error = 1.0459829, gradient norm = 0.0006560
# [t-SNE] Iteration 99: error = 1.0429539, gradient norm = 0.0006424
# [t-SNE] Iteration 100: error = 1.0401041, gradient norm = 0.0006259
# [t-SNE] Iteration 101: error = 1.0374475, gradient norm = 0.0006373
# [t-SNE] Iteration 102: error = 1.0347856, gradient norm = 0.0006297
# [t-SNE] Iteration 103: error = 1.0321089, gradient norm = 0.0006134
# [t-SNE] Iteration 104: error = 1.0294433, gradient norm = 0.0005948
# [t-SNE] Iteration 105: error = 1.0268150, gradient norm = 0.0005751
# [t-SNE] Iteration 106: error = 1.0242458, gradient norm = 0.0005664
# [t-SNE] Iteration 107: error = 1.0217184, gradient norm = 0.0005694
# [t-SNE] Iteration 108: error = 1.0191993, gradient norm = 0.0005702
# [t-SNE] Iteration 109: error = 1.0166756, gradient norm = 0.0005678
# [t-SNE] Iteration 110: error = 1.0141466, gradient norm = 0.0005598
# [t-SNE] Iteration 111: error = 1.0116212, gradient norm = 0.0005525
# [t-SNE] Iteration 112: error = 1.0091096, gradient norm = 0.0005428
# [t-SNE] Iteration 113: error = 1.0066300, gradient norm = 0.0005321
# [t-SNE] Iteration 114: error = 1.0041960, gradient norm = 0.0005295
# [t-SNE] Iteration 115: error = 1.0018076, gradient norm = 0.0005125
# [t-SNE] Iteration 116: error = 0.9994833, gradient norm = 0.0004917
# [t-SNE] Iteration 117: error = 0.9972430, gradient norm = 0.0004781
# [t-SNE] Iteration 118: error = 0.9950864, gradient norm = 0.0004691
# [t-SNE] Iteration 119: error = 0.9930049, gradient norm = 0.0004577
# [t-SNE] Iteration 120: error = 0.9909919, gradient norm = 0.0004439
# [t-SNE] Iteration 121: error = 0.9890411, gradient norm = 0.0004354
# [t-SNE] Iteration 122: error = 0.9871384, gradient norm = 0.0004338
# [t-SNE] Iteration 123: error = 0.9852709, gradient norm = 0.0004325
# [t-SNE] Iteration 124: error = 0.9834344, gradient norm = 0.0004253
# [t-SNE] Iteration 125: error = 0.9816387, gradient norm = 0.0004184
# [t-SNE] Iteration 126: error = 0.9798831, gradient norm = 0.0004199
# [t-SNE] Iteration 127: error = 0.9781510, gradient norm = 0.0004219
# [t-SNE] Iteration 128: error = 0.9764325, gradient norm = 0.0004160
# [t-SNE] Iteration 129: error = 0.9747260, gradient norm = 0.0004121
# [t-SNE] Iteration 130: error = 0.9730334, gradient norm = 0.0004005
# [t-SNE] Iteration 131: error = 0.9713633, gradient norm = 0.0003947
# [t-SNE] Iteration 132: error = 0.9697202, gradient norm = 0.0003881
# [t-SNE] Iteration 133: error = 0.9681028, gradient norm = 0.0003895
# [t-SNE] Iteration 134: error = 0.9665079, gradient norm = 0.0003884
# [t-SNE] Iteration 135: error = 0.9649381, gradient norm = 0.0003892
# [t-SNE] Iteration 136: error = 0.9633834, gradient norm = 0.0003761
# [t-SNE] Iteration 137: error = 0.9618524, gradient norm = 0.0003693
# [t-SNE] Iteration 138: error = 0.9603453, gradient norm = 0.0003627
# [t-SNE] Iteration 139: error = 0.9588711, gradient norm = 0.0003578
# [t-SNE] Iteration 140: error = 0.9574339, gradient norm = 0.0003561
# [t-SNE] Iteration 141: error = 0.9560303, gradient norm = 0.0003575
# [t-SNE] Iteration 142: error = 0.9546538, gradient norm = 0.0003563
# [t-SNE] Iteration 143: error = 0.9532990, gradient norm = 0.0003462
# [t-SNE] Iteration 144: error = 0.9519679, gradient norm = 0.0003421
# [t-SNE] Iteration 145: error = 0.9506600, gradient norm = 0.0003376
# [t-SNE] Iteration 146: error = 0.9493736, gradient norm = 0.0003311
# [t-SNE] Iteration 147: error = 0.9481077, gradient norm = 0.0003256
# [t-SNE] Iteration 148: error = 0.9468603, gradient norm = 0.0003188
# [t-SNE] Iteration 149: error = 0.9456310, gradient norm = 0.0003165
# [t-SNE] Iteration 150: error = 0.9444166, gradient norm = 0.0003147
# [t-SNE] Iteration 151: error = 0.9432152, gradient norm = 0.0003099
# [t-SNE] Iteration 152: error = 0.9420278, gradient norm = 0.0003061
# [t-SNE] Iteration 153: error = 0.9408551, gradient norm = 0.0003005
# [t-SNE] Iteration 154: error = 0.9396993, gradient norm = 0.0002978
# [t-SNE] Iteration 155: error = 0.9385583, gradient norm = 0.0002969
# [t-SNE] Iteration 156: error = 0.9374287, gradient norm = 0.0002946
# [t-SNE] Iteration 157: error = 0.9363097, gradient norm = 0.0002946
# [t-SNE] Iteration 158: error = 0.9351978, gradient norm = 0.0002940
# [t-SNE] Iteration 159: error = 0.9340903, gradient norm = 0.0002929
# [t-SNE] Iteration 160: error = 0.9329842, gradient norm = 0.0002941
# [t-SNE] Iteration 161: error = 0.9318750, gradient norm = 0.0002967
# [t-SNE] Iteration 162: error = 0.9307569, gradient norm = 0.0003012
# [t-SNE] Iteration 163: error = 0.9296256, gradient norm = 0.0002998
# [t-SNE] Iteration 164: error = 0.9284841, gradient norm = 0.0002999
# [t-SNE] Iteration 165: error = 0.9273347, gradient norm = 0.0003032
# [t-SNE] Iteration 166: error = 0.9261733, gradient norm = 0.0003067
# [t-SNE] Iteration 167: error = 0.9249943, gradient norm = 0.0003112
# [t-SNE] Iteration 168: error = 0.9237938, gradient norm = 0.0003157
# [t-SNE] Iteration 169: error = 0.9225687, gradient norm = 0.0003175
# [t-SNE] Iteration 170: error = 0.9213176, gradient norm = 0.0003174
# [t-SNE] Iteration 171: error = 0.9200411, gradient norm = 0.0003168
# [t-SNE] Iteration 172: error = 0.9187391, gradient norm = 0.0003181
# [t-SNE] Iteration 173: error = 0.9174092, gradient norm = 0.0003248
# [t-SNE] Iteration 174: error = 0.9160372, gradient norm = 0.0003400
# [t-SNE] Iteration 175: error = 0.9147130, gradient norm = 0.0003404
# [t-SNE] Iteration 176: error = 0.9136860, gradient norm = 0.0004612
# [t-SNE] Iteration 177: error = 0.9127470, gradient norm = 0.0005034
# [t-SNE] Iteration 178: error = 0.9117111, gradient norm = 0.0005002
# [t-SNE] Iteration 179: error = 0.9105939, gradient norm = 0.0004203
# [t-SNE] Iteration 180: error = 0.9098372, gradient norm = 0.0004897
# [t-SNE] Iteration 181: error = 0.9092287, gradient norm = 0.0005361
# [t-SNE] Iteration 182: error = 0.9083588, gradient norm = 0.0005113
# [t-SNE] Iteration 183: error = 0.9072867, gradient norm = 0.0004446
# [t-SNE] Iteration 184: error = 0.9063504, gradient norm = 0.0003790
# [t-SNE] Iteration 185: error = 0.9055572, gradient norm = 0.0003784
# [t-SNE] Iteration 186: error = 0.9047510, gradient norm = 0.0003754
# [t-SNE] Iteration 187: error = 0.9039214, gradient norm = 0.0003789
# [t-SNE] Iteration 188: error = 0.9030716, gradient norm = 0.0003744
# [t-SNE] Iteration 189: error = 0.9022107, gradient norm = 0.0003573
# [t-SNE] Iteration 190: error = 0.9013582, gradient norm = 0.0003355
# [t-SNE] Iteration 191: error = 0.9005371, gradient norm = 0.0003291
# [t-SNE] Iteration 192: error = 0.8997508, gradient norm = 0.0003391
# [t-SNE] Iteration 193: error = 0.8989853, gradient norm = 0.0003423
# [t-SNE] Iteration 194: error = 0.8982436, gradient norm = 0.0003462
# [t-SNE] Iteration 195: error = 0.8975120, gradient norm = 0.0003362
# [t-SNE] Iteration 196: error = 0.8967869, gradient norm = 0.0003171
# [t-SNE] Iteration 197: error = 0.8960745, gradient norm = 0.0003050
# [t-SNE] Iteration 198: error = 0.8953678, gradient norm = 0.0002940
# [t-SNE] Iteration 199: error = 0.8946678, gradient norm = 0.0002863
# [t-SNE] Iteration 200: error = 0.8939739, gradient norm = 0.0002878
# [t-SNE] Iteration 201: error = 0.8932737, gradient norm = 0.0003060
# [t-SNE] Iteration 202: error = 0.8925468, gradient norm = 0.0003248
# [t-SNE] Iteration 203: error = 0.8917937, gradient norm = 0.0003198
# [t-SNE] Iteration 204: error = 0.8910595, gradient norm = 0.0003180
# [t-SNE] Iteration 205: error = 0.8903632, gradient norm = 0.0003149
# [t-SNE] Iteration 206: error = 0.8897118, gradient norm = 0.0003131
# [t-SNE] Iteration 207: error = 0.8890927, gradient norm = 0.0003144
# [t-SNE] Iteration 208: error = 0.8884830, gradient norm = 0.0003112
# [t-SNE] Iteration 209: error = 0.8878727, gradient norm = 0.0002956
# [t-SNE] Iteration 210: error = 0.8872657, gradient norm = 0.0002756
# [t-SNE] Iteration 211: error = 0.8866644, gradient norm = 0.0002668
# [t-SNE] Iteration 212: error = 0.8860655, gradient norm = 0.0002661
# [t-SNE] Iteration 213: error = 0.8854644, gradient norm = 0.0002651
# [t-SNE] Iteration 214: error = 0.8848616, gradient norm = 0.0002585
# [t-SNE] Iteration 215: error = 0.8842626, gradient norm = 0.0002474
# [t-SNE] Iteration 216: error = 0.8836739, gradient norm = 0.0002402
# [t-SNE] Iteration 217: error = 0.8830981, gradient norm = 0.0002391
# [t-SNE] Iteration 218: error = 0.8825313, gradient norm = 0.0002461
# [t-SNE] Iteration 219: error = 0.8819634, gradient norm = 0.0002529
# [t-SNE] Iteration 220: error = 0.8813870, gradient norm = 0.0002498
# [t-SNE] Iteration 221: error = 0.8808021, gradient norm = 0.0002384
# [t-SNE] Iteration 222: error = 0.8802135, gradient norm = 0.0002284
# [t-SNE] Iteration 223: error = 0.8796218, gradient norm = 0.0002215
# [t-SNE] Iteration 224: error = 0.8790230, gradient norm = 0.0002223
# [t-SNE] Iteration 225: error = 0.8784054, gradient norm = 0.0002414
# [t-SNE] Iteration 226: error = 0.8777411, gradient norm = 0.0002865
# [t-SNE] Iteration 227: error = 0.8769836, gradient norm = 0.0003215
# [t-SNE] Iteration 228: error = 0.8762004, gradient norm = 0.0002995
# [t-SNE] Iteration 229: error = 0.8755142, gradient norm = 0.0003031
# [t-SNE] Iteration 230: error = 0.8748965, gradient norm = 0.0003383
# [t-SNE] Iteration 231: error = 0.8742488, gradient norm = 0.0003512
# [t-SNE] Iteration 232: error = 0.8735598, gradient norm = 0.0002942
# [t-SNE] Iteration 233: error = 0.8729389, gradient norm = 0.0002900
# [t-SNE] Iteration 234: error = 0.8723246, gradient norm = 0.0002851
# [t-SNE] Iteration 235: error = 0.8717070, gradient norm = 0.0002704
# [t-SNE] Iteration 236: error = 0.8711029, gradient norm = 0.0002542
# [t-SNE] Iteration 237: error = 0.8705275, gradient norm = 0.0002495
# [t-SNE] Iteration 238: error = 0.8699938, gradient norm = 0.0002667
# [t-SNE] Iteration 239: error = 0.8694710, gradient norm = 0.0002678
# [t-SNE] Iteration 240: error = 0.8689825, gradient norm = 0.0002678
# [t-SNE] Iteration 241: error = 0.8685470, gradient norm = 0.0002789
# [t-SNE] Iteration 242: error = 0.8681343, gradient norm = 0.0002701
# [t-SNE] Iteration 243: error = 0.8677244, gradient norm = 0.0002466
# [t-SNE] Iteration 244: error = 0.8673271, gradient norm = 0.0002412
# [t-SNE] Iteration 245: error = 0.8669345, gradient norm = 0.0002415
# [t-SNE] Iteration 246: error = 0.8665390, gradient norm = 0.0002317
# [t-SNE] Iteration 247: error = 0.8661418, gradient norm = 0.0002213
# [t-SNE] Iteration 248: error = 0.8657421, gradient norm = 0.0002070
# [t-SNE] Iteration 249: error = 0.8653452, gradient norm = 0.0001960
# [t-SNE] Iteration 250: error = 0.8649553, gradient norm = 0.0001888
# [t-SNE] Iteration 251: error = 0.8645726, gradient norm = 0.0001848
# [t-SNE] Iteration 252: error = 0.8641957, gradient norm = 0.0001828
# [t-SNE] Iteration 253: error = 0.8638232, gradient norm = 0.0001800
# [t-SNE] Iteration 254: error = 0.8634541, gradient norm = 0.0001737
# [t-SNE] Iteration 255: error = 0.8630890, gradient norm = 0.0001690
# [t-SNE] Iteration 256: error = 0.8627270, gradient norm = 0.0001641
# [t-SNE] Iteration 257: error = 0.8623677, gradient norm = 0.0001599
# [t-SNE] Iteration 258: error = 0.8620113, gradient norm = 0.0001565
# [t-SNE] Iteration 259: error = 0.8616579, gradient norm = 0.0001538
# [t-SNE] Iteration 260: error = 0.8613076, gradient norm = 0.0001515
# [t-SNE] Iteration 261: error = 0.8609606, gradient norm = 0.0001489
# [t-SNE] Iteration 262: error = 0.8606174, gradient norm = 0.0001481
# [t-SNE] Iteration 263: error = 0.8602775, gradient norm = 0.0001475
# [t-SNE] Iteration 264: error = 0.8599400, gradient norm = 0.0001477
# [t-SNE] Iteration 265: error = 0.8596041, gradient norm = 0.0001450
# [t-SNE] Iteration 266: error = 0.8592702, gradient norm = 0.0001430
# [t-SNE] Iteration 267: error = 0.8589380, gradient norm = 0.0001405
# [t-SNE] Iteration 268: error = 0.8586079, gradient norm = 0.0001377
# [t-SNE] Iteration 269: error = 0.8582800, gradient norm = 0.0001357
# [t-SNE] Iteration 270: error = 0.8579542, gradient norm = 0.0001339
# [t-SNE] Iteration 271: error = 0.8576304, gradient norm = 0.0001331
# [t-SNE] Iteration 272: error = 0.8573086, gradient norm = 0.0001320
# [t-SNE] Iteration 273: error = 0.8569886, gradient norm = 0.0001313
# [t-SNE] Iteration 274: error = 0.8566703, gradient norm = 0.0001304
# [t-SNE] Iteration 275: error = 0.8563537, gradient norm = 0.0001300
# [t-SNE] Iteration 276: error = 0.8560385, gradient norm = 0.0001305
# [t-SNE] Iteration 277: error = 0.8557247, gradient norm = 0.0001301
# [t-SNE] Iteration 278: error = 0.8554123, gradient norm = 0.0001274
# [t-SNE] Iteration 279: error = 0.8551017, gradient norm = 0.0001278
# [t-SNE] Iteration 280: error = 0.8547930, gradient norm = 0.0001281
# [t-SNE] Iteration 281: error = 0.8544856, gradient norm = 0.0001254
# [t-SNE] Iteration 282: error = 0.8541798, gradient norm = 0.0001252
# [t-SNE] Iteration 283: error = 0.8538758, gradient norm = 0.0001232
# [t-SNE] Iteration 284: error = 0.8535734, gradient norm = 0.0001227
# [t-SNE] Iteration 285: error = 0.8532727, gradient norm = 0.0001221
# [t-SNE] Iteration 286: error = 0.8529736, gradient norm = 0.0001205
# [t-SNE] Iteration 287: error = 0.8526758, gradient norm = 0.0001208
# [t-SNE] Iteration 288: error = 0.8523792, gradient norm = 0.0001204
# [t-SNE] Iteration 289: error = 0.8520837, gradient norm = 0.0001198
# [t-SNE] Iteration 290: error = 0.8517891, gradient norm = 0.0001204
# [t-SNE] Iteration 291: error = 0.8514956, gradient norm = 0.0001193
# [t-SNE] Iteration 292: error = 0.8512031, gradient norm = 0.0001202
# [t-SNE] Iteration 293: error = 0.8509115, gradient norm = 0.0001201
# [t-SNE] Iteration 294: error = 0.8506208, gradient norm = 0.0001198
# [t-SNE] Iteration 295: error = 0.8503311, gradient norm = 0.0001201
# [t-SNE] Iteration 296: error = 0.8500426, gradient norm = 0.0001199
# [t-SNE] Iteration 297: error = 0.8497556, gradient norm = 0.0001193
# [t-SNE] Iteration 298: error = 0.8494705, gradient norm = 0.0001190
# [t-SNE] Iteration 299: error = 0.8491874, gradient norm = 0.0001178
# [t-SNE] Iteration 300: error = 0.8489068, gradient norm = 0.0001196
# [t-SNE] Iteration 301: error = 0.8486281, gradient norm = 0.0001184
# [t-SNE] Iteration 302: error = 0.8483511, gradient norm = 0.0001143
# [t-SNE] Iteration 303: error = 0.8480770, gradient norm = 0.0001141
# [t-SNE] Iteration 304: error = 0.8478053, gradient norm = 0.0001151
# [t-SNE] Iteration 305: error = 0.8475357, gradient norm = 0.0001145
# [t-SNE] Iteration 306: error = 0.8472683, gradient norm = 0.0001133
# [t-SNE] Iteration 307: error = 0.8470032, gradient norm = 0.0001122
# [t-SNE] Iteration 308: error = 0.8467404, gradient norm = 0.0001116
# [t-SNE] Iteration 309: error = 0.8464799, gradient norm = 0.0001111
# [t-SNE] Iteration 310: error = 0.8462212, gradient norm = 0.0001103
# [t-SNE] Iteration 311: error = 0.8459645, gradient norm = 0.0001087
# [t-SNE] Iteration 312: error = 0.8457098, gradient norm = 0.0001084
# [t-SNE] Iteration 313: error = 0.8454569, gradient norm = 0.0001077
# [t-SNE] Iteration 314: error = 0.8452060, gradient norm = 0.0001077
# [t-SNE] Iteration 315: error = 0.8449567, gradient norm = 0.0001061
# [t-SNE] Iteration 316: error = 0.8447091, gradient norm = 0.0001056
# [t-SNE] Iteration 317: error = 0.8444633, gradient norm = 0.0001062
# [t-SNE] Iteration 318: error = 0.8442192, gradient norm = 0.0001060
# [t-SNE] Iteration 319: error = 0.8439766, gradient norm = 0.0001056
# [t-SNE] Iteration 320: error = 0.8437357, gradient norm = 0.0001061
# [t-SNE] Iteration 321: error = 0.8434962, gradient norm = 0.0001043
# [t-SNE] Iteration 322: error = 0.8432585, gradient norm = 0.0001045
# [t-SNE] Iteration 323: error = 0.8430225, gradient norm = 0.0001060
# [t-SNE] Iteration 324: error = 0.8427880, gradient norm = 0.0001079
# [t-SNE] Iteration 325: error = 0.8425548, gradient norm = 0.0001058
# [t-SNE] Iteration 326: error = 0.8423230, gradient norm = 0.0001031
# [t-SNE] Iteration 327: error = 0.8420935, gradient norm = 0.0001025
# [t-SNE] Iteration 328: error = 0.8418658, gradient norm = 0.0001038
# [t-SNE] Iteration 329: error = 0.8416394, gradient norm = 0.0001021
# [t-SNE] Iteration 330: error = 0.8414146, gradient norm = 0.0001007
# [t-SNE] Iteration 331: error = 0.8411915, gradient norm = 0.0001004
# [t-SNE] Iteration 332: error = 0.8409698, gradient norm = 0.0001009
# [t-SNE] Iteration 333: error = 0.8407495, gradient norm = 0.0000997
# [t-SNE] Iteration 334: error = 0.8405303, gradient norm = 0.0000986
# [t-SNE] Iteration 335: error = 0.8403127, gradient norm = 0.0000983
# [t-SNE] Iteration 336: error = 0.8400962, gradient norm = 0.0000989
# [t-SNE] Iteration 337: error = 0.8398807, gradient norm = 0.0000983
# [t-SNE] Iteration 338: error = 0.8396662, gradient norm = 0.0000976
# [t-SNE] Iteration 339: error = 0.8394530, gradient norm = 0.0000981
# [t-SNE] Iteration 340: error = 0.8392409, gradient norm = 0.0000990
# [t-SNE] Iteration 341: error = 0.8390297, gradient norm = 0.0000987
# [t-SNE] Iteration 342: error = 0.8388198, gradient norm = 0.0000978
# [t-SNE] Iteration 343: error = 0.8386110, gradient norm = 0.0000986
# [t-SNE] Iteration 344: error = 0.8384034, gradient norm = 0.0000976
# [t-SNE] Iteration 345: error = 0.8381969, gradient norm = 0.0000967
# [t-SNE] Iteration 346: error = 0.8379918, gradient norm = 0.0000969
# [t-SNE] Iteration 347: error = 0.8377879, gradient norm = 0.0000959
# [t-SNE] Iteration 348: error = 0.8375849, gradient norm = 0.0000957
# [t-SNE] Iteration 349: error = 0.8373831, gradient norm = 0.0000950
# [t-SNE] Iteration 350: error = 0.8371823, gradient norm = 0.0000951
# [t-SNE] Iteration 351: error = 0.8369825, gradient norm = 0.0000942
# [t-SNE] Iteration 352: error = 0.8367836, gradient norm = 0.0000947
# [t-SNE] Iteration 353: error = 0.8365856, gradient norm = 0.0000937
# [t-SNE] Iteration 354: error = 0.8363884, gradient norm = 0.0000942
# [t-SNE] Iteration 355: error = 0.8361922, gradient norm = 0.0000946
# [t-SNE] Iteration 356: error = 0.8359966, gradient norm = 0.0000933
# [t-SNE] Iteration 357: error = 0.8358019, gradient norm = 0.0000923
# [t-SNE] Iteration 358: error = 0.8356081, gradient norm = 0.0000922
# [t-SNE] Iteration 359: error = 0.8354150, gradient norm = 0.0000925
# [t-SNE] Iteration 360: error = 0.8352225, gradient norm = 0.0000922
# [t-SNE] Iteration 361: error = 0.8350305, gradient norm = 0.0000923
# [t-SNE] Iteration 362: error = 0.8348391, gradient norm = 0.0000926
# [t-SNE] Iteration 363: error = 0.8346479, gradient norm = 0.0000933
# [t-SNE] Iteration 364: error = 0.8344571, gradient norm = 0.0000942
# [t-SNE] Iteration 365: error = 0.8342664, gradient norm = 0.0000945
# [t-SNE] Iteration 366: error = 0.8340757, gradient norm = 0.0000939
# [t-SNE] Iteration 367: error = 0.8338851, gradient norm = 0.0000927
# [t-SNE] Iteration 368: error = 0.8336946, gradient norm = 0.0000932
# [t-SNE] Iteration 369: error = 0.8335036, gradient norm = 0.0000923
# [t-SNE] Iteration 370: error = 0.8333120, gradient norm = 0.0000923
# [t-SNE] Iteration 371: error = 0.8331195, gradient norm = 0.0000931
# [t-SNE] Iteration 372: error = 0.8329252, gradient norm = 0.0000941
# [t-SNE] Iteration 373: error = 0.8327287, gradient norm = 0.0000943
# [t-SNE] Iteration 374: error = 0.8325293, gradient norm = 0.0000965
# [t-SNE] Iteration 375: error = 0.8323260, gradient norm = 0.0000992
# [t-SNE] Iteration 376: error = 0.8321175, gradient norm = 0.0001013
# [t-SNE] Iteration 377: error = 0.8319026, gradient norm = 0.0001028
# [t-SNE] Iteration 378: error = 0.8316800, gradient norm = 0.0001051
# [t-SNE] Iteration 379: error = 0.8314482, gradient norm = 0.0001092
# [t-SNE] Iteration 380: error = 0.8312055, gradient norm = 0.0001120
# [t-SNE] Iteration 381: error = 0.8309509, gradient norm = 0.0001158
# [t-SNE] Iteration 382: error = 0.8306836, gradient norm = 0.0001195
# [t-SNE] Iteration 383: error = 0.8304029, gradient norm = 0.0001215
# [t-SNE] Iteration 384: error = 0.8301093, gradient norm = 0.0001237
# [t-SNE] Iteration 385: error = 0.8298029, gradient norm = 0.0001262
# [t-SNE] Iteration 386: error = 0.8294836, gradient norm = 0.0001281
# [t-SNE] Iteration 387: error = 0.8291516, gradient norm = 0.0001302
# [t-SNE] Iteration 388: error = 0.8288073, gradient norm = 0.0001315
# [t-SNE] Iteration 389: error = 0.8284528, gradient norm = 0.0001318
# [t-SNE] Iteration 390: error = 0.8280978, gradient norm = 0.0001272
# [t-SNE] Iteration 391: error = 0.8277801, gradient norm = 0.0001097
# [t-SNE] Iteration 392: error = 0.8276031, gradient norm = 0.0001676
# [t-SNE] Iteration 393: error = 0.8275298, gradient norm = 0.0002604
# [t-SNE] Iteration 394: error = 0.8273811, gradient norm = 0.0002718
# [t-SNE] Iteration 395: error = 0.8271499, gradient norm = 0.0002254
# [t-SNE] Iteration 396: error = 0.8269335, gradient norm = 0.0001831
# [t-SNE] Iteration 397: error = 0.8267637, gradient norm = 0.0001893
# [t-SNE] Iteration 398: error = 0.8266018, gradient norm = 0.0001818
# [t-SNE] Iteration 399: error = 0.8264486, gradient norm = 0.0001740
# [t-SNE] Iteration 400: error = 0.8262937, gradient norm = 0.0001569
# [t-SNE] Iteration 401: error = 0.8261357, gradient norm = 0.0001422
# [t-SNE] Iteration 402: error = 0.8259768, gradient norm = 0.0001392
# [t-SNE] Iteration 403: error = 0.8258156, gradient norm = 0.0001367
# [t-SNE] Iteration 404: error = 0.8256547, gradient norm = 0.0001322
# [t-SNE] Iteration 405: error = 0.8254972, gradient norm = 0.0001227
# [t-SNE] Iteration 406: error = 0.8253445, gradient norm = 0.0001140
# [t-SNE] Iteration 407: error = 0.8251954, gradient norm = 0.0001080
# [t-SNE] Iteration 408: error = 0.8250482, gradient norm = 0.0001049
# [t-SNE] Iteration 409: error = 0.8249025, gradient norm = 0.0001035
# [t-SNE] Iteration 410: error = 0.8247580, gradient norm = 0.0001006
# [t-SNE] Iteration 411: error = 0.8246152, gradient norm = 0.0001002
# [t-SNE] Iteration 412: error = 0.8244735, gradient norm = 0.0001000
# [t-SNE] Iteration 413: error = 0.8243326, gradient norm = 0.0000976
# [t-SNE] Iteration 414: error = 0.8241924, gradient norm = 0.0000955
# [t-SNE] Iteration 415: error = 0.8240529, gradient norm = 0.0000920
# [t-SNE] Iteration 416: error = 0.8239142, gradient norm = 0.0000890
# [t-SNE] Iteration 417: error = 0.8237764, gradient norm = 0.0000876
# [t-SNE] Iteration 418: error = 0.8236395, gradient norm = 0.0000865
# [t-SNE] Iteration 419: error = 0.8235031, gradient norm = 0.0000844
# [t-SNE] Iteration 420: error = 0.8233673, gradient norm = 0.0000827
# [t-SNE] Iteration 421: error = 0.8232321, gradient norm = 0.0000808
# [t-SNE] Iteration 422: error = 0.8230975, gradient norm = 0.0000785
# [t-SNE] Iteration 423: error = 0.8229635, gradient norm = 0.0000781
# [t-SNE] Iteration 424: error = 0.8228301, gradient norm = 0.0000771
# [t-SNE] Iteration 425: error = 0.8226973, gradient norm = 0.0000757
# [t-SNE] Iteration 426: error = 0.8225652, gradient norm = 0.0000762
# [t-SNE] Iteration 427: error = 0.8224336, gradient norm = 0.0000758
# [t-SNE] Iteration 428: error = 0.8223025, gradient norm = 0.0000748
# [t-SNE] Iteration 429: error = 0.8221719, gradient norm = 0.0000749
# [t-SNE] Iteration 430: error = 0.8220419, gradient norm = 0.0000749
# [t-SNE] Iteration 431: error = 0.8219123, gradient norm = 0.0000741
# [t-SNE] Iteration 432: error = 0.8217832, gradient norm = 0.0000740
# [t-SNE] Iteration 433: error = 0.8216547, gradient norm = 0.0000737
# [t-SNE] Iteration 434: error = 0.8215265, gradient norm = 0.0000738
# [t-SNE] Iteration 435: error = 0.8213989, gradient norm = 0.0000743
# [t-SNE] Iteration 436: error = 0.8212717, gradient norm = 0.0000747
# [t-SNE] Iteration 437: error = 0.8211449, gradient norm = 0.0000741
# [t-SNE] Iteration 438: error = 0.8210189, gradient norm = 0.0000738
# [t-SNE] Iteration 439: error = 0.8208935, gradient norm = 0.0000751
# [t-SNE] Iteration 440: error = 0.8207686, gradient norm = 0.0000748
# [t-SNE] Iteration 441: error = 0.8206442, gradient norm = 0.0000729
# [t-SNE] Iteration 442: error = 0.8205207, gradient norm = 0.0000733
# [t-SNE] Iteration 443: error = 0.8203979, gradient norm = 0.0000738
# [t-SNE] Iteration 444: error = 0.8202757, gradient norm = 0.0000722
# [t-SNE] Iteration 445: error = 0.8201542, gradient norm = 0.0000730
# [t-SNE] Iteration 446: error = 0.8200333, gradient norm = 0.0000720
# [t-SNE] Iteration 447: error = 0.8199130, gradient norm = 0.0000709
# [t-SNE] Iteration 448: error = 0.8197931, gradient norm = 0.0000710
# [t-SNE] Iteration 449: error = 0.8196738, gradient norm = 0.0000709
# [t-SNE] Iteration 450: error = 0.8195547, gradient norm = 0.0000702
# [t-SNE] Iteration 451: error = 0.8194360, gradient norm = 0.0000701
# [t-SNE] Iteration 452: error = 0.8193175, gradient norm = 0.0000700
# [t-SNE] Iteration 453: error = 0.8191993, gradient norm = 0.0000700
# [t-SNE] Iteration 454: error = 0.8190811, gradient norm = 0.0000701
# [t-SNE] Iteration 455: error = 0.8189629, gradient norm = 0.0000699
# [t-SNE] Iteration 456: error = 0.8188448, gradient norm = 0.0000699
# [t-SNE] Iteration 457: error = 0.8187267, gradient norm = 0.0000699
# [t-SNE] Iteration 458: error = 0.8186084, gradient norm = 0.0000700
# [t-SNE] Iteration 459: error = 0.8184900, gradient norm = 0.0000701
# [t-SNE] Iteration 460: error = 0.8183714, gradient norm = 0.0000710
# [t-SNE] Iteration 461: error = 0.8182527, gradient norm = 0.0000721
# [t-SNE] Iteration 462: error = 0.8181335, gradient norm = 0.0000727
# [t-SNE] Iteration 463: error = 0.8180140, gradient norm = 0.0000729
# [t-SNE] Iteration 464: error = 0.8178941, gradient norm = 0.0000726
# [t-SNE] Iteration 465: error = 0.8177738, gradient norm = 0.0000711
# [t-SNE] Iteration 466: error = 0.8176532, gradient norm = 0.0000726
# [t-SNE] Iteration 467: error = 0.8175321, gradient norm = 0.0000734
# [t-SNE] Iteration 468: error = 0.8174103, gradient norm = 0.0000747
# [t-SNE] Iteration 469: error = 0.8172879, gradient norm = 0.0000743
# [t-SNE] Iteration 470: error = 0.8171648, gradient norm = 0.0000750
# [t-SNE] Iteration 471: error = 0.8170411, gradient norm = 0.0000747
# [t-SNE] Iteration 472: error = 0.8169169, gradient norm = 0.0000753
# [t-SNE] Iteration 473: error = 0.8167924, gradient norm = 0.0000756
# [t-SNE] Iteration 474: error = 0.8166676, gradient norm = 0.0000749
# [t-SNE] Iteration 475: error = 0.8165428, gradient norm = 0.0000754
# [t-SNE] Iteration 476: error = 0.8164181, gradient norm = 0.0000749
# [t-SNE] Iteration 477: error = 0.8162937, gradient norm = 0.0000754
# [t-SNE] Iteration 478: error = 0.8161697, gradient norm = 0.0000750
# [t-SNE] Iteration 479: error = 0.8160464, gradient norm = 0.0000745
# [t-SNE] Iteration 480: error = 0.8159241, gradient norm = 0.0000745
# [t-SNE] Iteration 481: error = 0.8158030, gradient norm = 0.0000744
# [t-SNE] Iteration 482: error = 0.8156833, gradient norm = 0.0000737
# [t-SNE] Iteration 483: error = 0.8155653, gradient norm = 0.0000735
# [t-SNE] Iteration 484: error = 0.8154489, gradient norm = 0.0000708
# [t-SNE] Iteration 485: error = 0.8153342, gradient norm = 0.0000698
# [t-SNE] Iteration 486: error = 0.8152211, gradient norm = 0.0000722
# [t-SNE] Iteration 487: error = 0.8151089, gradient norm = 0.0000705
# [t-SNE] Iteration 488: error = 0.8149976, gradient norm = 0.0000687
# [t-SNE] Iteration 489: error = 0.8148875, gradient norm = 0.0000692
# [t-SNE] Iteration 490: error = 0.8147783, gradient norm = 0.0000676
# [t-SNE] Iteration 491: error = 0.8146703, gradient norm = 0.0000670
# [t-SNE] Iteration 492: error = 0.8145632, gradient norm = 0.0000670
# [t-SNE] Iteration 493: error = 0.8144570, gradient norm = 0.0000659
# [t-SNE] Iteration 494: error = 0.8143518, gradient norm = 0.0000650
# [t-SNE] Iteration 495: error = 0.8142475, gradient norm = 0.0000653
# [t-SNE] Iteration 496: error = 0.8141438, gradient norm = 0.0000649
# [t-SNE] Iteration 497: error = 0.8140410, gradient norm = 0.0000641
# [t-SNE] Iteration 498: error = 0.8139388, gradient norm = 0.0000636
# [t-SNE] Iteration 499: error = 0.8138371, gradient norm = 0.0000639
# [t-SNE] Iteration 500: error = 0.8137360, gradient norm = 0.0000638
# [t-SNE] Iteration 501: error = 0.8136352, gradient norm = 0.0000639
# [t-SNE] Iteration 502: error = 0.8135346, gradient norm = 0.0000645
# [t-SNE] Iteration 503: error = 0.8134345, gradient norm = 0.0000640
# [t-SNE] Iteration 504: error = 0.8133353, gradient norm = 0.0000649
# [t-SNE] Iteration 505: error = 0.8132370, gradient norm = 0.0000652
# [t-SNE] Iteration 506: error = 0.8131389, gradient norm = 0.0000646
# [t-SNE] Iteration 507: error = 0.8130413, gradient norm = 0.0000641
# [t-SNE] Iteration 508: error = 0.8129442, gradient norm = 0.0000632
# [t-SNE] Iteration 509: error = 0.8128478, gradient norm = 0.0000634
# [t-SNE] Iteration 510: error = 0.8127520, gradient norm = 0.0000643
# [t-SNE] Iteration 511: error = 0.8126563, gradient norm = 0.0000638
# [t-SNE] Iteration 512: error = 0.8125609, gradient norm = 0.0000625
# [t-SNE] Iteration 513: error = 0.8124659, gradient norm = 0.0000623
# [t-SNE] Iteration 514: error = 0.8123712, gradient norm = 0.0000627
# [t-SNE] Iteration 515: error = 0.8122767, gradient norm = 0.0000632
# [t-SNE] Iteration 516: error = 0.8121823, gradient norm = 0.0000631
# [t-SNE] Iteration 517: error = 0.8120881, gradient norm = 0.0000633
# [t-SNE] Iteration 518: error = 0.8119941, gradient norm = 0.0000630
# [t-SNE] Iteration 519: error = 0.8119002, gradient norm = 0.0000635
# [t-SNE] Iteration 520: error = 0.8118065, gradient norm = 0.0000633
# [t-SNE] Iteration 521: error = 0.8117129, gradient norm = 0.0000627
# [t-SNE] Iteration 522: error = 0.8116195, gradient norm = 0.0000623
# [t-SNE] Iteration 523: error = 0.8115263, gradient norm = 0.0000624
# [t-SNE] Iteration 524: error = 0.8114333, gradient norm = 0.0000627
# [t-SNE] Iteration 525: error = 0.8113403, gradient norm = 0.0000629
# [t-SNE] Iteration 526: error = 0.8112474, gradient norm = 0.0000621
# [t-SNE] Iteration 527: error = 0.8111546, gradient norm = 0.0000620
# [t-SNE] Iteration 528: error = 0.8110618, gradient norm = 0.0000615
# [t-SNE] Iteration 529: error = 0.8109690, gradient norm = 0.0000609
# [t-SNE] Iteration 530: error = 0.8108762, gradient norm = 0.0000611
# [t-SNE] Iteration 531: error = 0.8107834, gradient norm = 0.0000615
# [t-SNE] Iteration 532: error = 0.8106903, gradient norm = 0.0000619
# [t-SNE] Iteration 533: error = 0.8105971, gradient norm = 0.0000616
# [t-SNE] Iteration 534: error = 0.8105038, gradient norm = 0.0000609
# [t-SNE] Iteration 535: error = 0.8104105, gradient norm = 0.0000616
# [t-SNE] Iteration 536: error = 0.8103170, gradient norm = 0.0000620
# [t-SNE] Iteration 537: error = 0.8102233, gradient norm = 0.0000623
# [t-SNE] Iteration 538: error = 0.8101295, gradient norm = 0.0000621
# [t-SNE] Iteration 539: error = 0.8100355, gradient norm = 0.0000624
# [t-SNE] Iteration 540: error = 0.8099415, gradient norm = 0.0000632
# [t-SNE] Iteration 541: error = 0.8098473, gradient norm = 0.0000630
# [t-SNE] Iteration 542: error = 0.8097530, gradient norm = 0.0000616
# [t-SNE] Iteration 543: error = 0.8096587, gradient norm = 0.0000613
# [t-SNE] Iteration 544: error = 0.8095644, gradient norm = 0.0000622
# [t-SNE] Iteration 545: error = 0.8094700, gradient norm = 0.0000627
# [t-SNE] Iteration 546: error = 0.8093753, gradient norm = 0.0000624
# [t-SNE] Iteration 547: error = 0.8092806, gradient norm = 0.0000623
# [t-SNE] Iteration 548: error = 0.8091858, gradient norm = 0.0000630
# [t-SNE] Iteration 549: error = 0.8090908, gradient norm = 0.0000638
# [t-SNE] Iteration 550: error = 0.8089957, gradient norm = 0.0000640
# [t-SNE] Iteration 551: error = 0.8089005, gradient norm = 0.0000636
# [t-SNE] Iteration 552: error = 0.8088054, gradient norm = 0.0000639
# [t-SNE] Iteration 553: error = 0.8087102, gradient norm = 0.0000635
# [t-SNE] Iteration 554: error = 0.8086149, gradient norm = 0.0000618
# [t-SNE] Iteration 555: error = 0.8085198, gradient norm = 0.0000612
# [t-SNE] Iteration 556: error = 0.8084247, gradient norm = 0.0000619
# [t-SNE] Iteration 557: error = 0.8083295, gradient norm = 0.0000619
# [t-SNE] Iteration 558: error = 0.8082344, gradient norm = 0.0000615
# [t-SNE] Iteration 559: error = 0.8081393, gradient norm = 0.0000617
# [t-SNE] Iteration 560: error = 0.8080442, gradient norm = 0.0000618
# [t-SNE] Iteration 561: error = 0.8079493, gradient norm = 0.0000620
# [t-SNE] Iteration 562: error = 0.8078545, gradient norm = 0.0000624
# [t-SNE] Iteration 563: error = 0.8077599, gradient norm = 0.0000622
# [t-SNE] Iteration 564: error = 0.8076654, gradient norm = 0.0000613
# [t-SNE] Iteration 565: error = 0.8075713, gradient norm = 0.0000620
# [t-SNE] Iteration 566: error = 0.8074773, gradient norm = 0.0000617
# [t-SNE] Iteration 567: error = 0.8073834, gradient norm = 0.0000612
# [t-SNE] Iteration 568: error = 0.8072896, gradient norm = 0.0000611
# [t-SNE] Iteration 569: error = 0.8071959, gradient norm = 0.0000610
# [t-SNE] Iteration 570: error = 0.8071021, gradient norm = 0.0000611
# [t-SNE] Iteration 571: error = 0.8070081, gradient norm = 0.0000611
# [t-SNE] Iteration 572: error = 0.8069141, gradient norm = 0.0000613
# [t-SNE] Iteration 573: error = 0.8068198, gradient norm = 0.0000612
# [t-SNE] Iteration 574: error = 0.8067253, gradient norm = 0.0000612
# [t-SNE] Iteration 575: error = 0.8066307, gradient norm = 0.0000617
# [t-SNE] Iteration 576: error = 0.8065358, gradient norm = 0.0000616
# [t-SNE] Iteration 577: error = 0.8064406, gradient norm = 0.0000618
# [t-SNE] Iteration 578: error = 0.8063452, gradient norm = 0.0000620
# [t-SNE] Iteration 579: error = 0.8062495, gradient norm = 0.0000624
# [t-SNE] Iteration 580: error = 0.8061535, gradient norm = 0.0000632
# [t-SNE] Iteration 581: error = 0.8060571, gradient norm = 0.0000637
# [t-SNE] Iteration 582: error = 0.8059603, gradient norm = 0.0000629
# [t-SNE] Iteration 583: error = 0.8058632, gradient norm = 0.0000630
# [t-SNE] Iteration 584: error = 0.8057658, gradient norm = 0.0000645
# [t-SNE] Iteration 585: error = 0.8056680, gradient norm = 0.0000657
# [t-SNE] Iteration 586: error = 0.8055696, gradient norm = 0.0000651
# [t-SNE] Iteration 587: error = 0.8054706, gradient norm = 0.0000636
# [t-SNE] Iteration 588: error = 0.8053712, gradient norm = 0.0000643
# [t-SNE] Iteration 589: error = 0.8052711, gradient norm = 0.0000646
# [t-SNE] Iteration 590: error = 0.8051702, gradient norm = 0.0000642
# [t-SNE] Iteration 591: error = 0.8050683, gradient norm = 0.0000641
# [t-SNE] Iteration 592: error = 0.8049650, gradient norm = 0.0000647
# [t-SNE] Iteration 593: error = 0.8048600, gradient norm = 0.0000651
# [t-SNE] Iteration 594: error = 0.8047527, gradient norm = 0.0000665
# [t-SNE] Iteration 595: error = 0.8046423, gradient norm = 0.0000687
# [t-SNE] Iteration 596: error = 0.8045273, gradient norm = 0.0000699
# [t-SNE] Iteration 597: error = 0.8044056, gradient norm = 0.0000726
# [t-SNE] Iteration 598: error = 0.8042737, gradient norm = 0.0000784
# [t-SNE] Iteration 599: error = 0.8041248, gradient norm = 0.0000868
# [t-SNE] Iteration 600: error = 0.8039453, gradient norm = 0.0001004
# [t-SNE] Iteration 601: error = 0.8037186, gradient norm = 0.0001139
# [t-SNE] Iteration 602: error = 0.8037420, gradient norm = 0.0003527
# [t-SNE] Iteration 603: error = 0.8035384, gradient norm = 0.0002384
# [t-SNE] Iteration 604: error = 0.8035174, gradient norm = 0.0003252
# [t-SNE] Iteration 605: error = 0.8034056, gradient norm = 0.0003138
# [t-SNE] Iteration 606: error = 0.8032409, gradient norm = 0.0002454
# [t-SNE] Iteration 607: error = 0.8031126, gradient norm = 0.0001843
# [t-SNE] Iteration 608: error = 0.8030612, gradient norm = 0.0002294
# [t-SNE] Iteration 609: error = 0.8029668, gradient norm = 0.0002191
# [t-SNE] Iteration 610: error = 0.8028512, gradient norm = 0.0001636
# [t-SNE] Iteration 611: error = 0.8027654, gradient norm = 0.0002242
# [t-SNE] Iteration 612: error = 0.8026416, gradient norm = 0.0001408
# [t-SNE] Iteration 613: error = 0.8025483, gradient norm = 0.0001592
# [t-SNE] Iteration 614: error = 0.8024644, gradient norm = 0.0001936
# [t-SNE] Iteration 615: error = 0.8023599, gradient norm = 0.0001328
# [t-SNE] Iteration 616: error = 0.8022703, gradient norm = 0.0001200
# [t-SNE] Iteration 617: error = 0.8021907, gradient norm = 0.0001629
# [t-SNE] Iteration 618: error = 0.8020996, gradient norm = 0.0001653
# [t-SNE] Iteration 619: error = 0.8019985, gradient norm = 0.0001237
# [t-SNE] Iteration 620: error = 0.8019022, gradient norm = 0.0000821
# [t-SNE] Iteration 621: error = 0.8018165, gradient norm = 0.0000942
# [t-SNE] Iteration 622: error = 0.8017344, gradient norm = 0.0001157
# [t-SNE] Iteration 623: error = 0.8016505, gradient norm = 0.0001176
# [t-SNE] Iteration 624: error = 0.8015653, gradient norm = 0.0001029
# [t-SNE] Iteration 625: error = 0.8014811, gradient norm = 0.0000841
# [t-SNE] Iteration 626: error = 0.8013996, gradient norm = 0.0000772
# [t-SNE] Iteration 627: error = 0.8013200, gradient norm = 0.0000829
# [t-SNE] Iteration 628: error = 0.8012406, gradient norm = 0.0000890
# [t-SNE] Iteration 629: error = 0.8011602, gradient norm = 0.0000874
# [t-SNE] Iteration 630: error = 0.8010791, gradient norm = 0.0000798
# [t-SNE] Iteration 631: error = 0.8009982, gradient norm = 0.0000707
# [t-SNE] Iteration 632: error = 0.8009183, gradient norm = 0.0000659
# [t-SNE] Iteration 633: error = 0.8008394, gradient norm = 0.0000663
# [t-SNE] Iteration 634: error = 0.8007610, gradient norm = 0.0000676
# [t-SNE] Iteration 635: error = 0.8006827, gradient norm = 0.0000685
# [t-SNE] Iteration 636: error = 0.8006044, gradient norm = 0.0000677
# [t-SNE] Iteration 637: error = 0.8005260, gradient norm = 0.0000652
# [t-SNE] Iteration 638: error = 0.8004476, gradient norm = 0.0000632
# [t-SNE] Iteration 639: error = 0.8003693, gradient norm = 0.0000620
# [t-SNE] Iteration 640: error = 0.8002910, gradient norm = 0.0000621
# [t-SNE] Iteration 641: error = 0.8002128, gradient norm = 0.0000631
# [t-SNE] Iteration 642: error = 0.8001346, gradient norm = 0.0000653
# [t-SNE] Iteration 643: error = 0.8000562, gradient norm = 0.0000664
# [t-SNE] Iteration 644: error = 0.7999776, gradient norm = 0.0000652
# [t-SNE] Iteration 645: error = 0.7998987, gradient norm = 0.0000629
# [t-SNE] Iteration 646: error = 0.7998198, gradient norm = 0.0000633
# [t-SNE] Iteration 647: error = 0.7997405, gradient norm = 0.0000632
# [t-SNE] Iteration 648: error = 0.7996610, gradient norm = 0.0000620
# [t-SNE] Iteration 649: error = 0.7995811, gradient norm = 0.0000621
# [t-SNE] Iteration 650: error = 0.7995010, gradient norm = 0.0000616
# [t-SNE] Iteration 651: error = 0.7994205, gradient norm = 0.0000619
# [t-SNE] Iteration 652: error = 0.7993395, gradient norm = 0.0000609
# [t-SNE] Iteration 653: error = 0.7992581, gradient norm = 0.0000610
# [t-SNE] Iteration 654: error = 0.7991762, gradient norm = 0.0000614
# [t-SNE] Iteration 655: error = 0.7990937, gradient norm = 0.0000611
# [t-SNE] Iteration 656: error = 0.7990106, gradient norm = 0.0000618
# [t-SNE] Iteration 657: error = 0.7989269, gradient norm = 0.0000624
# [t-SNE] Iteration 658: error = 0.7988424, gradient norm = 0.0000631
# [t-SNE] Iteration 659: error = 0.7987572, gradient norm = 0.0000619
# [t-SNE] Iteration 660: error = 0.7986714, gradient norm = 0.0000614
# [t-SNE] Iteration 661: error = 0.7985850, gradient norm = 0.0000619
# [t-SNE] Iteration 662: error = 0.7984978, gradient norm = 0.0000616
# [t-SNE] Iteration 663: error = 0.7984099, gradient norm = 0.0000613
# [t-SNE] Iteration 664: error = 0.7983212, gradient norm = 0.0000618
# [t-SNE] Iteration 665: error = 0.7982316, gradient norm = 0.0000620
# [t-SNE] Iteration 666: error = 0.7981409, gradient norm = 0.0000624
# [t-SNE] Iteration 667: error = 0.7980488, gradient norm = 0.0000630
# [t-SNE] Iteration 668: error = 0.7979552, gradient norm = 0.0000634
# [t-SNE] Iteration 669: error = 0.7978597, gradient norm = 0.0000636
# [t-SNE] Iteration 670: error = 0.7977620, gradient norm = 0.0000637
# [t-SNE] Iteration 671: error = 0.7976616, gradient norm = 0.0000648
# [t-SNE] Iteration 672: error = 0.7975581, gradient norm = 0.0000653
# [t-SNE] Iteration 673: error = 0.7974513, gradient norm = 0.0000661
# [t-SNE] Iteration 674: error = 0.7973416, gradient norm = 0.0000669
# [t-SNE] Iteration 675: error = 0.7972294, gradient norm = 0.0000680
# [t-SNE] Iteration 676: error = 0.7971154, gradient norm = 0.0000678
# [t-SNE] Iteration 677: error = 0.7970007, gradient norm = 0.0000689
# [t-SNE] Iteration 678: error = 0.7968859, gradient norm = 0.0000687
# [t-SNE] Iteration 679: error = 0.7967716, gradient norm = 0.0000680
# [t-SNE] Iteration 680: error = 0.7966583, gradient norm = 0.0000680
# [t-SNE] Iteration 681: error = 0.7965467, gradient norm = 0.0000676
# [t-SNE] Iteration 682: error = 0.7964373, gradient norm = 0.0000672
# [t-SNE] Iteration 683: error = 0.7963306, gradient norm = 0.0000679
# [t-SNE] Iteration 684: error = 0.7962266, gradient norm = 0.0000678
# [t-SNE] Iteration 685: error = 0.7961242, gradient norm = 0.0000694
# [t-SNE] Iteration 686: error = 0.7960215, gradient norm = 0.0000715
# [t-SNE] Iteration 687: error = 0.7959167, gradient norm = 0.0000738
# [t-SNE] Iteration 688: error = 0.7958091, gradient norm = 0.0000755
# [t-SNE] Iteration 689: error = 0.7956987, gradient norm = 0.0000756
# [t-SNE] Iteration 690: error = 0.7955855, gradient norm = 0.0000749
# [t-SNE] Iteration 691: error = 0.7954700, gradient norm = 0.0000754
# [t-SNE] Iteration 692: error = 0.7953523, gradient norm = 0.0000752
# [t-SNE] Iteration 693: error = 0.7952324, gradient norm = 0.0000746
# [t-SNE] Iteration 694: error = 0.7951103, gradient norm = 0.0000751
# ...
# [t-SNE] Iteration 766: error = 0.7711221, gradient norm = 0.0002024
# [t-SNE] Iteration 767: error = 0.7707078, gradient norm = 0.0001906
# [t-SNE] Iteration 768: error = 0.7703172, gradient norm = 0.0001786
# [t-SNE] Iteration 769: error = 0.7699553, gradient norm = 0.0001778
# [t-SNE] Iteration 770: error = 0.7696115, gradient norm = 0.0001820
# [t-SNE] Iteration 771: error = 0.7692822, gradient norm = 0.0001719
# [t-SNE] Iteration 772: error = 0.7689831, gradient norm = 0.0001754
# [t-SNE] Iteration 773: error = 0.7687055, gradient norm = 0.0001825
# [t-SNE] Iteration 774: error = 0.7684321, gradient norm = 0.0001737
# [t-SNE] Iteration 775: error = 0.7681698, gradient norm = 0.0001655
# [t-SNE] Iteration 776: error = 0.7679206, gradient norm = 0.0001605
# [t-SNE] Iteration 777: error = 0.7676822, gradient norm = 0.0001563
# [t-SNE] Iteration 778: error = 0.7674593, gradient norm = 0.0001508
# [t-SNE] Iteration 779: error = 0.7672556, gradient norm = 0.0001477
# [t-SNE] Iteration 780: error = 0.7670668, gradient norm = 0.0001418
# [t-SNE] Iteration 781: error = 0.7668877, gradient norm = 0.0001371
# [t-SNE] Iteration 782: error = 0.7667110, gradient norm = 0.0001325
# [t-SNE] Iteration 783: error = 0.7665363, gradient norm = 0.0001253
# [t-SNE] Iteration 784: error = 0.7663706, gradient norm = 0.0001267
# [t-SNE] Iteration 785: error = 0.7662094, gradient norm = 0.0001301
# [t-SNE] Iteration 786: error = 0.7660471, gradient norm = 0.0001263
# [t-SNE] Iteration 787: error = 0.7658847, gradient norm = 0.0001200
# [t-SNE] Iteration 788: error = 0.7657236, gradient norm = 0.0001119
# [t-SNE] Iteration 789: error = 0.7655659, gradient norm = 0.0001061
# [t-SNE] Iteration 790: error = 0.7654123, gradient norm = 0.0001060
# [t-SNE] Iteration 791: error = 0.7652614, gradient norm = 0.0001071
# [t-SNE] Iteration 792: error = 0.7651120, gradient norm = 0.0001063
# [t-SNE] Iteration 793: error = 0.7649636, gradient norm = 0.0001039
# [t-SNE] Iteration 794: error = 0.7648166, gradient norm = 0.0001015
# [t-SNE] Iteration 795: error = 0.7646714, gradient norm = 0.0000986
# [t-SNE] Iteration 796: error = 0.7645282, gradient norm = 0.0000977
# [t-SNE] Iteration 797: error = 0.7643871, gradient norm = 0.0000969
# [t-SNE] Iteration 798: error = 0.7642477, gradient norm = 0.0000958
# [t-SNE] Iteration 799: error = 0.7641102, gradient norm = 0.0000947
# [t-SNE] Iteration 800: error = 0.7639744, gradient norm = 0.0000931
# [t-SNE] Iteration 801: error = 0.7638406, gradient norm = 0.0000915
# [t-SNE] Iteration 802: error = 0.7637089, gradient norm = 0.0000898
# [t-SNE] Iteration 803: error = 0.7635795, gradient norm = 0.0000878
# [t-SNE] Iteration 804: error = 0.7634526, gradient norm = 0.0000860
# [t-SNE] Iteration 805: error = 0.7633283, gradient norm = 0.0000829
# [t-SNE] Iteration 806: error = 0.7632071, gradient norm = 0.0000826
# [t-SNE] Iteration 807: error = 0.7630887, gradient norm = 0.0000812
# [t-SNE] Iteration 808: error = 0.7629727, gradient norm = 0.0000795
# [t-SNE] Iteration 809: error = 0.7628592, gradient norm = 0.0000778
# [t-SNE] Iteration 810: error = 0.7627483, gradient norm = 0.0000764
# [t-SNE] Iteration 811: error = 0.7626394, gradient norm = 0.0000758
# [t-SNE] Iteration 812: error = 0.7625326, gradient norm = 0.0000748
# [t-SNE] Iteration 813: error = 0.7624277, gradient norm = 0.0000753
# [t-SNE] Iteration 814: error = 0.7623245, gradient norm = 0.0000745
# [t-SNE] Iteration 815: error = 0.7622227, gradient norm = 0.0000724
# [t-SNE] Iteration 816: error = 0.7621226, gradient norm = 0.0000717
# [t-SNE] Iteration 817: error = 0.7620241, gradient norm = 0.0000720
# [t-SNE] Iteration 818: error = 0.7619266, gradient norm = 0.0000716
# [t-SNE] Iteration 819: error = 0.7618301, gradient norm = 0.0000718
# [t-SNE] Iteration 820: error = 0.7617345, gradient norm = 0.0000717
# [t-SNE] Iteration 821: error = 0.7616393, gradient norm = 0.0000723
# [t-SNE] Iteration 822: error = 0.7615441, gradient norm = 0.0000727
# [t-SNE] Iteration 823: error = 0.7614491, gradient norm = 0.0000726
# [t-SNE] Iteration 824: error = 0.7613547, gradient norm = 0.0000716
# [t-SNE] Iteration 825: error = 0.7612625, gradient norm = 0.0000709
# [t-SNE] Iteration 826: error = 0.7611729, gradient norm = 0.0000738
# [t-SNE] Iteration 827: error = 0.7610839, gradient norm = 0.0000765
# [t-SNE] Iteration 828: error = 0.7609942, gradient norm = 0.0000748
# [t-SNE] Iteration 829: error = 0.7609042, gradient norm = 0.0000710
# [t-SNE] Iteration 830: error = 0.7608152, gradient norm = 0.0000688
# [t-SNE] Iteration 831: error = 0.7607276, gradient norm = 0.0000683
# [t-SNE] Iteration 832: error = 0.7606409, gradient norm = 0.0000683
# [t-SNE] Iteration 833: error = 0.7605549, gradient norm = 0.0000675
# [t-SNE] Iteration 834: error = 0.7604698, gradient norm = 0.0000669
# [t-SNE] Iteration 835: error = 0.7603858, gradient norm = 0.0000662
# [t-SNE] Iteration 836: error = 0.7603032, gradient norm = 0.0000655
# [t-SNE] Iteration 837: error = 0.7602220, gradient norm = 0.0000646
# [t-SNE] Iteration 838: error = 0.7601422, gradient norm = 0.0000641
# [t-SNE] Iteration 839: error = 0.7600638, gradient norm = 0.0000651
# [t-SNE] Iteration 840: error = 0.7599863, gradient norm = 0.0000670
# [t-SNE] Iteration 841: error = 0.7599091, gradient norm = 0.0000691
# [t-SNE] Iteration 842: error = 0.7598317, gradient norm = 0.0000710
# [t-SNE] Iteration 843: error = 0.7597536, gradient norm = 0.0000723
# [t-SNE] Iteration 844: error = 0.7596746, gradient norm = 0.0000727
# [t-SNE] Iteration 845: error = 0.7595943, gradient norm = 0.0000720
# [t-SNE] Iteration 846: error = 0.7595128, gradient norm = 0.0000736
# [t-SNE] Iteration 847: error = 0.7594296, gradient norm = 0.0000766
# [t-SNE] Iteration 848: error = 0.7593435, gradient norm = 0.0000783
# [t-SNE] Iteration 849: error = 0.7592537, gradient norm = 0.0000828
# [t-SNE] Iteration 850: error = 0.7591578, gradient norm = 0.0000870
# [t-SNE] Iteration 851: error = 0.7590525, gradient norm = 0.0000943
# [t-SNE] Iteration 852: error = 0.7589315, gradient norm = 0.0001047
# [t-SNE] Iteration 853: error = 0.7587827, gradient norm = 0.0001211
# [t-SNE] Iteration 854: error = 0.7585907, gradient norm = 0.0001401
# [t-SNE] Iteration 855: error = 0.7585546, gradient norm = 0.0002745
# [t-SNE] Iteration 856: error = 0.7584048, gradient norm = 0.0002450
# [t-SNE] Iteration 857: error = 0.7583077, gradient norm = 0.0002532
# [t-SNE] Iteration 858: error = 0.7581341, gradient norm = 0.0001510
# [t-SNE] Iteration 859: error = 0.7580498, gradient norm = 0.0002132
# [t-SNE] Iteration 860: error = 0.7579339, gradient norm = 0.0002319
# [t-SNE] Iteration 861: error = 0.7577728, gradient norm = 0.0001876
# [t-SNE] Iteration 862: error = 0.7576101, gradient norm = 0.0001624
# [t-SNE] Iteration 863: error = 0.7574522, gradient norm = 0.0001790
# [t-SNE] Iteration 864: error = 0.7572816, gradient norm = 0.0001937
# [t-SNE] Iteration 865: error = 0.7570868, gradient norm = 0.0001839
# [t-SNE] Iteration 866: error = 0.7568745, gradient norm = 0.0001690
# [t-SNE] Iteration 867: error = 0.7566509, gradient norm = 0.0001667
# [t-SNE] Iteration 868: error = 0.7564172, gradient norm = 0.0001694
# [t-SNE] Iteration 869: error = 0.7561965, gradient norm = 0.0001813
# [t-SNE] Iteration 870: error = 0.7559953, gradient norm = 0.0002121
# [t-SNE] Iteration 871: error = 0.7557472, gradient norm = 0.0001902
# [t-SNE] Iteration 872: error = 0.7554966, gradient norm = 0.0001760
# [t-SNE] Iteration 873: error = 0.7552370, gradient norm = 0.0001687
# [t-SNE] Iteration 874: error = 0.7549774, gradient norm = 0.0001622
# [t-SNE] Iteration 875: error = 0.7547342, gradient norm = 0.0001704
# [t-SNE] Iteration 876: error = 0.7544903, gradient norm = 0.0001703
# [t-SNE] Iteration 877: error = 0.7542476, gradient norm = 0.0001672
# [t-SNE] Iteration 878: error = 0.7540105, gradient norm = 0.0001637
# [t-SNE] Iteration 879: error = 0.7537783, gradient norm = 0.0001546
# [t-SNE] Iteration 880: error = 0.7535548, gradient norm = 0.0001416
# [t-SNE] Iteration 881: error = 0.7533450, gradient norm = 0.0001346
# [t-SNE] Iteration 882: error = 0.7531479, gradient norm = 0.0001339
# [t-SNE] Iteration 883: error = 0.7529587, gradient norm = 0.0001324
# [t-SNE] Iteration 884: error = 0.7527749, gradient norm = 0.0001248
# [t-SNE] Iteration 885: error = 0.7525985, gradient norm = 0.0001181
# [t-SNE] Iteration 886: error = 0.7524308, gradient norm = 0.0001119
# [t-SNE] Iteration 887: error = 0.7522707, gradient norm = 0.0001038
# [t-SNE] Iteration 888: error = 0.7521175, gradient norm = 0.0001012
# [t-SNE] Iteration 889: error = 0.7519700, gradient norm = 0.0000993
# [t-SNE] Iteration 890: error = 0.7518273, gradient norm = 0.0000964
# [t-SNE] Iteration 891: error = 0.7516887, gradient norm = 0.0000959
# [t-SNE] Iteration 892: error = 0.7515530, gradient norm = 0.0000943
# [t-SNE] Iteration 893: error = 0.7514197, gradient norm = 0.0000925
# [t-SNE] Iteration 894: error = 0.7512880, gradient norm = 0.0000909
# [t-SNE] Iteration 895: error = 0.7511576, gradient norm = 0.0000881
# [t-SNE] Iteration 896: error = 0.7510283, gradient norm = 0.0000866
# [t-SNE] Iteration 897: error = 0.7509000, gradient norm = 0.0000853
# [t-SNE] Iteration 898: error = 0.7507721, gradient norm = 0.0000844
# [t-SNE] Iteration 899: error = 0.7506444, gradient norm = 0.0000830
# [t-SNE] Iteration 900: error = 0.7505170, gradient norm = 0.0000817
# [t-SNE] Iteration 901: error = 0.7503897, gradient norm = 0.0000802
# [t-SNE] Iteration 902: error = 0.7502625, gradient norm = 0.0000793
# [t-SNE] Iteration 903: error = 0.7501354, gradient norm = 0.0000787
# [t-SNE] Iteration 904: error = 0.7500082, gradient norm = 0.0000778
# [t-SNE] Iteration 905: error = 0.7498811, gradient norm = 0.0000775
# [t-SNE] Iteration 906: error = 0.7497539, gradient norm = 0.0000771
# [t-SNE] Iteration 907: error = 0.7496268, gradient norm = 0.0000767
# [t-SNE] Iteration 908: error = 0.7494996, gradient norm = 0.0000766
# [t-SNE] Iteration 909: error = 0.7493726, gradient norm = 0.0000757
# [t-SNE] Iteration 910: error = 0.7492458, gradient norm = 0.0000751
# [t-SNE] Iteration 911: error = 0.7491194, gradient norm = 0.0000741
# [t-SNE] Iteration 912: error = 0.7489936, gradient norm = 0.0000737
# [t-SNE] Iteration 913: error = 0.7488685, gradient norm = 0.0000742
# [t-SNE] Iteration 914: error = 0.7487444, gradient norm = 0.0000739
# [t-SNE] Iteration 915: error = 0.7486217, gradient norm = 0.0000776
# [t-SNE] Iteration 916: error = 0.7485004, gradient norm = 0.0000814
# [t-SNE] Iteration 917: error = 0.7483805, gradient norm = 0.0000781
# [t-SNE] Iteration 918: error = 0.7482626, gradient norm = 0.0000735
# [t-SNE] Iteration 919: error = 0.7481480, gradient norm = 0.0000748
# [t-SNE] Iteration 920: error = 0.7480359, gradient norm = 0.0000715
# [t-SNE] Iteration 921: error = 0.7479271, gradient norm = 0.0000713
# [t-SNE] Iteration 922: error = 0.7478217, gradient norm = 0.0000748
# [t-SNE] Iteration 923: error = 0.7477189, gradient norm = 0.0000704
# [t-SNE] Iteration 924: error = 0.7476195, gradient norm = 0.0000678
# [t-SNE] Iteration 925: error = 0.7475236, gradient norm = 0.0000672
# [t-SNE] Iteration 926: error = 0.7474308, gradient norm = 0.0000674
# [t-SNE] Iteration 927: error = 0.7473408, gradient norm = 0.0000651
# [t-SNE] Iteration 928: error = 0.7472538, gradient norm = 0.0000614
# [t-SNE] Iteration 929: error = 0.7471700, gradient norm = 0.0000618
# [t-SNE] Iteration 930: error = 0.7470886, gradient norm = 0.0000604
# [t-SNE] Iteration 931: error = 0.7470097, gradient norm = 0.0000586
# [t-SNE] Iteration 932: error = 0.7469332, gradient norm = 0.0000594
# [t-SNE] Iteration 933: error = 0.7468584, gradient norm = 0.0000570
# [t-SNE] Iteration 934: error = 0.7467856, gradient norm = 0.0000563
# [t-SNE] Iteration 935: error = 0.7467143, gradient norm = 0.0000558
# [t-SNE] Iteration 936: error = 0.7466446, gradient norm = 0.0000559
# [t-SNE] Iteration 937: error = 0.7465760, gradient norm = 0.0000545
# [t-SNE] Iteration 938: error = 0.7465087, gradient norm = 0.0000540
# [t-SNE] Iteration 939: error = 0.7464423, gradient norm = 0.0000532
# [t-SNE] Iteration 940: error = 0.7463770, gradient norm = 0.0000540
# [t-SNE] Iteration 941: error = 0.7463125, gradient norm = 0.0000536
# [t-SNE] Iteration 942: error = 0.7462487, gradient norm = 0.0000525
# [t-SNE] Iteration 943: error = 0.7461856, gradient norm = 0.0000517
# [t-SNE] Iteration 944: error = 0.7461232, gradient norm = 0.0000516
# [t-SNE] Iteration 945: error = 0.7460614, gradient norm = 0.0000511
# [t-SNE] Iteration 946: error = 0.7460001, gradient norm = 0.0000503
# [t-SNE] Iteration 947: error = 0.7459394, gradient norm = 0.0000499
# [t-SNE] Iteration 948: error = 0.7458791, gradient norm = 0.0000499
# [t-SNE] Iteration 949: error = 0.7458193, gradient norm = 0.0000496
# [t-SNE] Iteration 950: error = 0.7457599, gradient norm = 0.0000490
# [t-SNE] Iteration 951: error = 0.7457009, gradient norm = 0.0000492
# [t-SNE] Iteration 952: error = 0.7456422, gradient norm = 0.0000490
# [t-SNE] Iteration 953: error = 0.7455839, gradient norm = 0.0000487
# [t-SNE] Iteration 954: error = 0.7455260, gradient norm = 0.0000487
# [t-SNE] Iteration 955: error = 0.7454684, gradient norm = 0.0000479
# [t-SNE] Iteration 956: error = 0.7454112, gradient norm = 0.0000479
# [t-SNE] Iteration 957: error = 0.7453544, gradient norm = 0.0000480
# [t-SNE] Iteration 958: error = 0.7452980, gradient norm = 0.0000475
# [t-SNE] Iteration 959: error = 0.7452419, gradient norm = 0.0000476
# [t-SNE] Iteration 960: error = 0.7451862, gradient norm = 0.0000468
# [t-SNE] Iteration 961: error = 0.7451310, gradient norm = 0.0000470
# [t-SNE] Iteration 962: error = 0.7450762, gradient norm = 0.0000469
# [t-SNE] Iteration 963: error = 0.7450218, gradient norm = 0.0000462
# [t-SNE] Iteration 964: error = 0.7449678, gradient norm = 0.0000461
# [t-SNE] Iteration 965: error = 0.7449142, gradient norm = 0.0000459
# [t-SNE] Iteration 966: error = 0.7448610, gradient norm = 0.0000461
# [t-SNE] Iteration 967: error = 0.7448080, gradient norm = 0.0000463
# [t-SNE] Iteration 968: error = 0.7447554, gradient norm = 0.0000455
# [t-SNE] Iteration 969: error = 0.7447030, gradient norm = 0.0000456
# [t-SNE] Iteration 970: error = 0.7446508, gradient norm = 0.0000457
# [t-SNE] Iteration 971: error = 0.7445988, gradient norm = 0.0000451
# [t-SNE] Iteration 972: error = 0.7445469, gradient norm = 0.0000460
# [t-SNE] Iteration 973: error = 0.7444950, gradient norm = 0.0000470
# [t-SNE] Iteration 974: error = 0.7444429, gradient norm = 0.0000476
# [t-SNE] Iteration 975: error = 0.7443902, gradient norm = 0.0000480
# [t-SNE] Iteration 976: error = 0.7443367, gradient norm = 0.0000497
# [t-SNE] Iteration 977: error = 0.7442817, gradient norm = 0.0000529
# [t-SNE] Iteration 978: error = 0.7442239, gradient norm = 0.0000560
# [t-SNE] Iteration 979: error = 0.7441645, gradient norm = 0.0000543
# [t-SNE] Iteration 980: error = 0.7441112, gradient norm = 0.0000578
# [t-SNE] Iteration 981: error = 0.7440635, gradient norm = 0.0000665
# [t-SNE] Iteration 982: error = 0.7440138, gradient norm = 0.0000631
# [t-SNE] Iteration 983: error = 0.7439634, gradient norm = 0.0000614
# [t-SNE] Iteration 984: error = 0.7439132, gradient norm = 0.0000626
# [t-SNE] Iteration 985: error = 0.7438623, gradient norm = 0.0000559
# [t-SNE] Iteration 986: error = 0.7438124, gradient norm = 0.0000501
# [t-SNE] Iteration 987: error = 0.7437641, gradient norm = 0.0000524
# [t-SNE] Iteration 988: error = 0.7437163, gradient norm = 0.0000553
# [t-SNE] Iteration 989: error = 0.7436680, gradient norm = 0.0000542
# [t-SNE] Iteration 990: error = 0.7436195, gradient norm = 0.0000504
# [t-SNE] Iteration 991: error = 0.7435713, gradient norm = 0.0000472
# [t-SNE] Iteration 992: error = 0.7435237, gradient norm = 0.0000463
# [t-SNE] Iteration 993: error = 0.7434765, gradient norm = 0.0000470
# [t-SNE] Iteration 994: error = 0.7434294, gradient norm = 0.0000472
# [t-SNE] Iteration 995: error = 0.7433824, gradient norm = 0.0000462
# [t-SNE] Iteration 996: error = 0.7433356, gradient norm = 0.0000458
# [t-SNE] Iteration 997: error = 0.7432889, gradient norm = 0.0000448
# [t-SNE] Iteration 998: error = 0.7432424, gradient norm = 0.0000438
# [t-SNE] Iteration 999: error = 0.7431960, gradient norm = 0.0000436
# [t-SNE] Iteration 1000: error = 0.7431498, gradient norm = 0.0000436

# %%
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y, legend='full', palette=palette)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
tsne = TSNE()
X_embedded = tsne.fit_transform(X)

sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y, legend='full', palette=palette)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
